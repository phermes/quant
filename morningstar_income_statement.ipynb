# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('bmw_income_statement.csv',skiprows=1)

# %%
df.columns[0]
# Out:
# 'Fiscal year ends in December. EUR in millions except per share data.'

# %%
if 'EUR' in df.columns[0]:
    print 'EUR'
if 'USD' in df.columns[0]:
    print 'USD'
# Out:
# EUR

# %%
df = pd.read_csv('MUV2_income_statement.csv',skiprows=1)

# %%
df
# Out:
#    Fiscal year ends in December. EUR in millions except per share data.  \
# 0                                            Revenues
# 1                                            Premiums
# 2                              Investment income, net
# 3                                 Other income (loss)
# 4                                      Total revenues
# 5                       Benefits, claims and expenses
# 6           Policyholder benefits and claims incurred
# 7                 Selling, general and administrative
# 8                                    Interest expense
# 9                                      Other expenses
# 10                Total benefits, claims and expenses
# 11                         Income before income taxes
# 12                       Income tax (expense) benefit
# 13                             Other income (expense)
# 14                                         Net income
# 15                                 Preferred dividend
# ...
