# %%
import plotly.dashboard_objs as dashboard
import IPython.display
import datetime
from IPython.display import Image
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import pandas as pd
import numpy as np
from QAnT import stock, Index
from QAnT.output import plot_key_quantities, keyratio_comparison, print_keyratio_summary
from QAnT.output import plot_global_comparisons

from ipywidgets import Button, HBox, VBox
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
s = stock(isin='DE0005790430')

# %%
s.get_summary()

# %%
s.quant_result
# Out:
#                        Name          ISIN             Parameter  Value Point
# 0  FUCHS PETROL.SE VZO O.N.  DE0005790430  OnlyPositiveEarnings      0     1
# 1  FUCHS PETROL.SE VZO O.N.  DE0005790430  AnnualEarningsGrowth   11.6     1
# 2  FUCHS PETROL.SE VZO O.N.  DE0005790430       BookValueGrowth  234.1     1
# 3  FUCHS PETROL.SE VZO O.N.  DE0005790430            PresentROE   22.8     1
# 4  FUCHS PETROL.SE VZO O.N.  DE0005790430           PresentRoIC   22.5     1
# 5  FUCHS PETROL.SE VZO O.N.  DE0005790430           EquityRatio   71.8     1
# 6  FUCHS PETROL.SE VZO O.N.  DE0005790430             EBTMargin   16.3     1
# 7  FUCHS PETROL.SE VZO O.N.  DE0005790430        DividendGrowth  316.4     1

# %% [markdown]
# ## Fundamentals

# %%
print_keyratio_summary(s)
# Out:
#     year currency  Equity    RoE  Revenue  NetIncome   EPS   Div  BookVal  \
# 0   2016      EUR   71.84  22.79   2267.0      259.0  1.86  0.82     8.10
# 1   2015      EUR   71.74  23.77   2079.0      236.0  1.69  0.77     7.22
# 2   2014      EUR   71.68  24.84   1866.0      220.0  1.57  0.70     6.23
# 3   2013      EUR   73.36  26.72   1831.0      218.0  1.53  0.65     5.92
# 4   2012      EUR   70.36  28.76   1819.0      206.0  1.45  0.50     5.21
# 5   2011      EUR   66.36  30.37   1652.0      182.0  1.28  0.45     4.26
# 6   2010      EUR   60.87  36.48   1458.0      170.0  1.20  0.29     3.49
# 7   2009      EUR   52.50  34.25   1178.0      120.0  0.84  0.27     2.21
# 8   2008      EUR   44.60  33.70   1394.0      109.0  0.74  0.25     2.36
# 9   2007      EUR   46.90  37.53   1365.0      119.0  0.77  0.17     1.94
# 10  2006      EUR   44.38  36.21   1323.0       96.0  0.62  0.13      NaN
# 11  2005      EUR   33.60  38.10   1192.0       74.2  0.52  0.10      NaN
# ...

# %%
global_plots = plot_global_comparisons(s)
global_plots.PER()
# Out:
# <div id="de92085d-7bf2-49cb-8578-53e8c16b11a6" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("de92085d-7bf2-49cb-8578-53e8c16b11a6", [{"type": "scatter", "x": ["2018-02-09", "2018-02-08", "2018-02-07", "2018-02-06", "2018-02-05", "2018-02-02", "2018-02-01", "2018-01-31", "2018-01-30", "2018-01-29", "2018-01-26", "2018-01-25", "2018-01-24", "2018-01-23", "2018-01-22", "2018-01-19", "2018-01-18", "2018-01-17", "2018-01-16", "2018-01-15", "2018-01-12", "2018-01-11", "2018-01-10", "2018-01-09", "2018-01-08", "2018-01-05", "2018-01-04", "2018-01-03", "2018-01-02", "2017-12-29", "2017-12-28", "2017-12-27", "2017-12-22", "2017-12-21", "2017-12-20", "2017-12-19", "2017-12-18", "2017-12-15", "2017-12-14", "2017-12-13", "2017-12-12", "2017-12-11", "2017-12-08", "2017-12-07", "2017-12-06", "2017-12-05", "201
# ...

# %%
plot_key_quantities(s)
# Out:
# <div id="c051ff81-9a93-4b5d-a2f4-db35c303413c" style="height: 600px; width: 1000px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("c051ff81-9a93-4b5d-a2f4-db35c303413c", [{"type": "scatter", "x": [2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000, 1999], "y": [1.86, 1.69, 1.57, 1.53, 1.45, 1.28, 1.2, 0.84, 0.74, 0.77, 0.62, 0.52, 0.27, 0.23, 0.18, 0.12, 0.13, 0.13], "name": "EarningsPerShare"}, {"type": "scatter", "x": [2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000, 1999], "y": [1.86, 1.58, 1.16, 1.02, 0.82, 0.94, 1.0, 0.41, 0.82, 0.47, null, null, null, null, null, null, null, null], "name": "FreeCashFlowPerShare"}, {"type": "scatter", "x": [2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 20
# ...

# %%
global_plots.keyratios()
# Out:
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]  [ (1,2) x2,y2 ]
# [ (2,1) x3,y3 ]  [ (2,2) x4,y4 ]
# ...

# %%
global_plots.risk()
# Out:
# <div id="2e1cfc48-cf1f-4aa5-bde6-1dddd15e0311" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("2e1cfc48-cf1f-4aa5-bde6-1dddd15e0311", [{"type": "scatter", "x": [-0.06090934128959605, -0.0588060542337791, -0.056702767177962146, -0.054599480122145196, -0.052496193066328245, -0.0503929060105113, -0.04828961895469435, -0.0461863318988774, -0.04408304484306045, -0.0419797577872435, -0.03987647073142655, -0.0377731836756096, -0.035669896619792654, -0.0335666095639757, -0.03146332250815875, -0.029360035452341803, -0.027256748396524852, -0.0251534613407079, -0.02305017428489095, -0.020946887229074, -0.01884360017325705, -0.016740313117440106, -0.014637026061623155, -0.012533739005806205, -0.010430451949989254, -0.008327164894172304, -0.006223877838355353, -0.0041205907825384025, -0.002017303726721459, 8.59
# ...

# %%
import sqlite3
cnx             = sqlite3.connect('database/stocks_dates.db')
allvar          = pd.read_sql_query("SELECT * FROM quarterly_report;", cnx)
cnx.close()

# %%
s.isin
# Out:
# 'DE0005790430'

# %%
qdates = allvar[allvar['isin']==s.isin]
qdates = qdates['report_date'].unique()
qdates.sort()
last_date = qdates[-1]
last_date = datetime.datetime.strptime(last_date,'%Y-%m-%d')
last_date = last_date.date()

# %%
import datetime
last_date
# Out:
# '2017-10-27'

# %%
s.quote['date'][0]
# Out:
# datetime.date(1999, 3, 16)

# %%
datetime.strptime(last_date)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-c8b7ca9148c4> in <module>()
# ----> 1 datetime.strptime(last_date)
#
# AttributeError: module 'datetime' has no attribute 'strptime'

# %%
s.quote[s.quote['date']==last_date]
# Out:
#             date                      name          isin   exchange currency  \
# 4778  2017-10-27  FUCHS PETROL.SE VZO O.N.  DE0005790430  Y FPE3.DE      EUR
#
#         open       high    low      close    volume    retabs    retrel
# 4778  48.105  48.900002  48.07  48.615002  203629.0  0.580002  0.012075

# %%
from QAnT import Index
b = Index()

# %%
quote_saved_dict[k]['retabs'] = quote_saved_dict[k]['close'].diff()
quote_saved_dict[k]['retrel'] = quote_saved_dict[k]['retabs']/quote_saved_dict[k]['close'].shift(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-e8ec62376198> in <module>()
# ----> 1 quote_saved_dict[k]['retabs'] = quote_saved_dict[k]['close'].diff()
#       2 quote_saved_dict[k]['retrel'] = quote_saved_dict[k]['retabs']/quote_saved_dict[k]['close'].shift(1)
#
# NameError: name 'quote_saved_dict' is not defined

# %%
s.quote['bla'] = s.quote['close'].diff()

# %%
quote_index = b._read_stored_quotes()

# %%
close = quote_index['close']

# %%
quote_index = quote_index.loc[quote_index['close']>1000]

# %%
quote_index.loc['test'] = close.diff()
# Out:
# /home/phermes/.conda/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
quote_index['retabs'] = close.diff()
# Out:
# /home/phermes/.conda/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
quote_index['retrel'] = quote_index['retabs']/quote_index['close'].shift(1)
# Out:
# /home/phermes/.conda/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
np.diff

# %%
b._read_stored_quotes()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-1c5d7d4e184f> in <module>()
# ----> 1 b._read_stored_quotes()
#
# /home/phermes/Dropbox/codes/python/170102_stocks_sql/QAnT/quotes.py in _read_stored_quotes(self)
#     139             # quote_saved_dict[k]['retrel'] = quote_saved_dict[k]['retabs']/quote_saved_dict[k]['close'].shift(1)
#     140
# --> 141             quote_saved_dict.loc[k, 'retabs'] = quote_saved_dict[k]['close'].diff()
#     142
#     143
#
# AttributeError: 'dict' object has no attribute 'loc'
